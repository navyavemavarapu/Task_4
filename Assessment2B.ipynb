# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv("/content/college_1.csv")
df2 = pd.read_csv("/content/college_2.csv")

# %%
df1.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %%
df2.tail(3)
# Out:
#          Name  python  python_en  mysql  computational_thinking  \
# 32       bala      32         49      0                      -1
# 33       XY Z      -1         20     -1                      -1
# 34  Hariharan      -1         -1     -1                       0
#
#     Previous Geekions  CodeKata Score  \
# 32               1720            1720
# 33                  0               0
# 34                  0               0
#
#                                    Department  Rising
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0

# %%
df = pd.merge(df1,df2,how='outer')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1208: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,

# %%
df.tail(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 116       bala    32.0    0.0               1720            1720
# 117       XY Z    -1.0   -1.0                  0               0
# 118  Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 116  Electronics and Communication Engineering       0       49.0
# 117           Computer Science and Engineering       0       20.0
# 118           Computer Science and Engineering       0       -1.0
#
#      computational_thinking
# 116                    -1.0
# 117                    -1.0
# 118                     0.0

# %%
df.isnull().sum()
# Out:
# Name                       0
# python                     0
# mysql                      0
# Previous Geekions          0
# CodeKata Score             0
# Department                 0
# Rising                     0
# python_en                 84
# computational_thinking    84
# dtype: int64

# %%
df.fillna((0),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               119 non-null    float64
#  8   computational_thinking  119 non-null    float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 9.3+ KB

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
exc_exp = df[df['CodeKata Score'] > 15000]

# %%
exc_exp.shape
# Out:
# (4, 9)

# %%
exc_exp
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        0.0
# 1         Computer Science and Engineering       0        0.0
# 2         Computer Science and Engineering       0        0.0
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      0.0
# 1                      0.0
# 2                      0.0
# 84                     9.0

# %%
exc_exp.to_csv("Exceeded expectations.csv")

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
reach_exp = df[(df['CodeKata Score'] < 15000) & (df['CodeKata Score'] > 10000)]

# %%
reach_exp.shape
# Out:
# (4, 9)

# %%
reach_exp
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        0.0
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      0.0
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %%
reach_exp.to_csv("Reached_expectations.csv")

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
need_imp = df[(df['CodeKata Score'] < 10000) & (df['CodeKata Score'] > 7000)]

# %%
need_imp.shape
# Out:
# (18, 9)

# %%
need_imp.head(3)
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4    Sathammai.S   100.0    8.0               8980            8980
# 5   NIVEESHWAR S   100.0    0.0               8200            8200
# 6  KALAIARASAN K    85.0   47.0               7750            7880
#
#                                   Department  Rising  python_en  \
# 4           Computer Science and Engineering       0        0.0
# 5           Computer Science and Engineering       0        0.0
# 6  Electronics and Communication Engineering     130        0.0
#
#    computational_thinking
# 4                     0.0
# 5                     0.0
# 6                     0.0

# %%
need_imp.to_csv("Needs_Improvement.csv")

# %% [markdown]
# # if codekate score < 7000 (Unsatisfactory.csv)

# %%
unsatis = df[df['CodeKata Score'] < 7000]

# %%
unsatis.shape
# Out:
# (93, 9)

# %%
unsatis.head()
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
#
#                                    Department  Rising  python_en  \
# 8   Electronics and Communication Engineering       0        0.0
# 9            Computer Science and Engineering       0        0.0
# 10  Electronics and Communication Engineering       0        0.0
# 11           Computer Science and Engineering       0        0.0
# 12           Computer Science and Engineering       0        0.0
#
#     computational_thinking
# 8                      0.0
# 9                      0.0
# 10                     0.0
# 11                     0.0
# ...

# %%
unsatis.to_csv("Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
cols = ['Previous Geekions', 'CodeKata Score']

avg = df[cols].mean()
avg
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %%
sns.barplot(x=cols,y=avg)
plt.title("Average of previous week geekions vs this week geekions",color='m',size=14)
plt.ylabel("Scores")
plt.show()

# %% [markdown]
# ###### No of students participated

# %%
x = len(df['Name'].unique())
print("Number of students participated:",x)
# Out:
# Number of students participated: 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
python_completion=df[df['python']==100]
python_completion.shape
# Out:
# (41, 9)

# %%
print("No of students completed the python course is:",python_completion.shape[0])
print("Total no.of students :",df.shape[0])
b=(python_completion.shape[0]/df.shape[0])*100
print("Percentage of students completed the python assignment is :",round(b))
# Out:
# No of students completed the python course is: 41
# Total no.of students : 119
# Percentage of students completed the python assignment is : 34

# %%
mysql_completion=df[df['mysql']==100]
mysql_completion.shape
# Out:
# (14, 9)

# %%
print("No of students completed the my_sql course is:",mysql_completion.shape[0])
print("Total no.of students :",df.shape[0])
g=(mysql_completion.shape[0]/df.shape[0])*100
print("Percentage of students completed the my_sql assignment is :",round(g))
# Out:
# No of students completed the my_sql course is: 14
# Total no.of students : 119
# Percentage of students completed the my_sql assignment is : 12

# %%
python_en_completion=df[df['python_en']==100]
python_en_completion.shape
# Out:
# (2, 9)

# %%
print("No of students completed the python_en course is:",python_en_completion.shape[0])
print("Total no.of students :",df.shape[0])
f=(python_en_completion.shape[0]/df.shape[0])*100
print("Percentage of students completed the python_en assignment is :",round(f))
# Out:
# No of students completed the python_en course is: 2
# Total no.of students : 119
# Percentage of students completed the python_en assignment is : 2

# %%
computational_thinking_completion=df[df['computational_thinking']==100]
computational_thinking_completion.shape
# Out:
# (0, 9)

# %%
print("No of students completed the computational_thinking course is:",computational_thinking_completion.shape[0])
print("Total no.of students :",df.shape[0])
f=(computational_thinking_completion.shape[0]/df.shape[0])*100
print("Percentage of students completed the computational_thinking assignment is :",round(f))
# Out:
# No of students completed the computational_thinking course is: 0
# Total no.of students : 119
# Percentage of students completed the computational_thinking assignment is : 0

# %%
Average=df.loc[(df['python']==100)|(df['mysql']==100)|(df['python_en']==100)|(df['computational_thinking']==100)]
Average.shape
# Out:
# (46, 9)

# %%
m=(Average.shape[0]/df.shape[0])*100
print("Average completion of python course or my_sql or python english or computational thinking is :",m)
# Out:
# Average completion of python course or my_sql or python english or computational thinking is : 38.655462184873954

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
weektop_performer = df.nlargest(3,'Rising')
weektop_performer
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking
# 92                      0.0
# 86                      6.0
# 102                     0.0

# %%
print('rising star of the week (top 3 candidate who performed well in that particular week) are:')
for i in weektop_performer['Name']:
  print(i)
# Out:
# rising star of the week (top 3 candidate who performed well in that particular week) are:
# shifak N
# Ganesh Ramkumar R
# Narasimhan Y L

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
overalltop_performer=df.nlargest(3, ['CodeKata Score'])
overalltop_performer
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0

# %%
print('Shining stars of the week (top 3 candidates who has highest geekions) are:')
for i in overalltop_performer['Name']:
  print(i)
# Out:
# Shining stars of the week (top 3 candidates who has highest geekions) are:
# A.Dharani
# V.JEEVITHA
# HEMAVATHI.R

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df['Department'].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
cse=df[df['Department']=='Computer Science and Engineering']
cse.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0

# %%
a = cse['CodeKata Score'].mean()
a
# Out:
# 5079.761904761905

# %%
ece=df[df['Department']=='Electronics and Communication Engineering']
ece.head(3)
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 6     KALAIARASAN K    85.0   47.0               7750            7880
# 8        J.SUGANTHI    27.0   50.0               5860            5860
# 10  Iyappan Samiraj    50.0   24.0               5400            5400
#
#                                    Department  Rising  python_en  \
# 6   Electronics and Communication Engineering     130        0.0
# 8   Electronics and Communication Engineering       0        0.0
# 10  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 6                      0.0
# 8                      0.0
# 10                     0.0

# %%
b = ece['CodeKata Score'].mean()
b
# Out:
# 2777.8205128205127

# %%
eee=df[df['Department']=='Electronics and Electrical Engineering']
eee.head(3)
# Out:
#            Name  python  mysql  Previous Geekions  CodeKata Score  \
# 64   k.parvathi   100.0  100.0                260             260
# 71  m.keerthana    97.5    0.0                120             120
# 72   Subhashini   100.0    4.0                120             120
#
#                                 Department  Rising  python_en  \
# 64  Electronics and Electrical Engineering       0        0.0
# 71  Electronics and Electrical Engineering       0        0.0
# 72  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 64                     0.0
# 71                     0.0
# 72                     0.0

# %%
c = ece['CodeKata Score'].mean()
c
# Out:
# 2777.8205128205127

# %%
y = np.array([a,b,c])
mylabels = ["CSE", "ECE", "EEE"]
plt.figure(figsize=(5,5))
plt.pie(y, labels = mylabels, autopct='%1.1f%%',radius=1.5)
plt.title('Department wise codekata performence')
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %% [markdown]
# **CSE toppers**

# %%
cse_toppers=cse.nlargest(10, ['CodeKata Score'])
cse_toppers.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0

# %%
plt.barh(cse_toppers['Name'],cse_toppers['CodeKata Score'])
plt.title('Computer science Toppers',color='m')
plt.xlabel('CodeKata Score',color='m')
plt.ylabel('Names',color='m')
plt.show()

# %% [markdown]
# **ECE toppers**

# %%
ece_toppers=ece.nlargest(10, ['CodeKata Score'])
ece_toppers.head(3)
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 87  Bodipudi Harini    -1.0   35.0              10040           10040
# 91        Gowtham R    -1.0    4.0               8650            8650
# 6     KALAIARASAN K    85.0   47.0               7750            7880
#
#                                    Department  Rising  python_en  \
# 87  Electronics and Communication Engineering       0        0.0
# 91  Electronics and Communication Engineering       0       60.0
# 6   Electronics and Communication Engineering     130        0.0
#
#     computational_thinking
# 87                    -1.0
# 91                     6.0
# 6                      0.0

# %%
plt.barh(ece_toppers['Name'],ece_toppers['CodeKata Score'])
plt.title('Electronics and Communication Engineering Toppers',color='m')
plt.xlabel('CodeKata Score',color='m')
plt.ylabel('Names',color='m')
plt.show()

# %% [markdown]
# **EEE toppers**

# %%
eee_toppers=eee.nlargest(10, ['CodeKata Score'])
eee_toppers.tail(3)
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 72       Subhashini   100.0    4.0                120             120
# 74  J.Bhuvaneshwari   100.0   20.0                100             100
# 75         santhosh    82.0   12.0                 60              60
#
#                                 Department  Rising  python_en  \
# 72  Electronics and Electrical Engineering       0        0.0
# 74  Electronics and Electrical Engineering       0        0.0
# 75  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 72                     0.0
# 74                     0.0
# 75                     0.0

# %%
plt.barh(eee_toppers['Name'],eee_toppers['CodeKata Score'])
plt.title('Electronics and Electrical Engineering Toppers',color='m')
plt.xlabel('CodeKata Score',color='m')
plt.ylabel('Names',color='m')
plt.show()
